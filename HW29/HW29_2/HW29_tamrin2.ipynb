# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
from PIL import ImageFont, ImageDraw, Image

# %%
logo = np.ones((600,1460,3) , dtype="uint8") * 70
plt.imshow(logo)

# %%
#red 

#maqadiro khode microsoft zade
logo[210:310 , 210:310] = (246, 83 , 20)

#blue
logo[320:420 , 210:310] = (0, 161, 241)
                           
#green
logo[210:310 , 320:420] = (124,  187, 0)
                           
#yellow 
logo[320:420 , 320:420] = (255, 187 , 0)

# text 

cv2.putText(logo , "Microsoft" , (450 , 350) , cv2.FONT_HERSHEY_TRIPLEX , 5, (255,255,255),5)

result=cv2.cvtColor(logo , cv2.COLOR_RGB2BGR)
cv2.imwrite("re.jpg" , result)

plt.imshow(logo)
